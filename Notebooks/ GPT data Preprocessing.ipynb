# %% [markdown]
# # Connect to Drive

# %%
#connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # install & imports

# %%
# !pip install pdfminer.six
# !python -m spacy download en_core_web_lg
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (42.0.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20231228
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# to work with DataFrames
import pandas as pd
# extract text from pdf
from pdfminer.high_level import extract_text
# clean text
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# info extraction
import spacy
from spacy import displacy
# topic modeling
from gensim import corpora, models
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # functions

# %% [markdown]
# ## extract text from pdf

# %%
def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)

# %% [markdown]
# ## clean text

# %%
def remove_html_tags(text):
    pattern = r'<(.*?)>'
    return re.sub(pattern, ' ', text)

def remove_html_entities(text):
    pattern = r'&\w+'
    return re.sub(pattern, ' ', text)

def replace_special_characters(text):
    pattern = r'[;:]|(\\r)|(\\n)'
    return re.sub(pattern, ' ', text)

def remove_extra_spaces(text):
    pattern = r'\s\s+?(?=\S)'
    return re.sub(pattern, ' ', text)

def replace_punctuation(text):
    punctuation = '!"#$%&\'()*,-./:;<=>?@[\\]^_`{|}~'
    return text.translate(str.maketrans(punctuation, ' ' * len(punctuation)))

def remove_non_ascii(text):
    return ''.join(char if ord(char) < 128 else ' ' for char in text)

def clean_text(text):
    text = remove_html_tags(text)
    text = remove_html_entities(text)
    text = replace_special_characters(text)
    text = replace_punctuation(text)
    text = remove_non_ascii(text)
    text = remove_extra_spaces(text)
    text = text.lower()
    return text

# %%
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# %% [markdown]
# ##extract informations

# %%
'''
note : the ruler has:
Number of degrees: 11
Number of majors: 268
Number of skills: 92983

'''
def get_skills(text):
    doc = nlp(text)
    skills = []
    for ent in doc.ents:
        if ent.label_ == "SKILL":
            skills.append(ent.text)
    return skills

def unique_skills(x):
    return list(set(x))

def get_degree(text):
    doc = nlp(text)
    degrees = []
    for ent in doc.ents:
        if ent.label_ == "DEGREE":
            degrees.append(ent.text)
    return degrees

def extract_sentence_after_degree(text):
    # Define the pattern to match "degree", "diploma", or "certificate", followed by 15-20 words.
    pattern = r"(?i)(?:degree|certificate|diploma|bachelor|high\s*school|associate|master|bsc|vocational|phd)\W+(?:\w+\W+){0,30}\w+"
    # Search for the pattern in the text
    match = re.search(pattern, text)
    # If a match is found, return the extracted text; otherwise, return None
    if match:
        return match.group(0)
    else:
        return None

def get_majors(text):
    doc = nlp(text)
    majors = []
    for ent in doc.ents:
        if ent.label_ == "MAJOR":
            majors.append(ent.text)
    return majors

# %% [markdown]
# ## topic modeling

# %%
# Load the LDA model
lda_model = models.LdaModel.load('/content/drive/MyDrive/LDA_models/lda_model_25')

def classify_text(lda_model, text):
    # Convert the new text to a bag-of-words vector
    new_text_bow = lda_model.id2word.doc2bow(text)

    # Get topic probabilities for the new text
    topic_probs = lda_model.get_document_topics(new_text_bow)  # List of tuples (topic ID, probability)

    # Sort topics by probability and extract the most dominant topic
    dominant_topic = max(topic_probs, key=lambda x: x[1])[0]

    return dominant_topic

# %% [markdown]
# # get datasets

# %%
users=pd.read_csv('/content/drive/MyDrive/data/chatgpt_datasets/users.csv')
apps=pd.read_csv('/content/drive/MyDrive/data/chatgpt_datasets/apps.csv')
jobs=pd.read_csv('/content/drive/MyDrive/data/chatgpt_datasets/jobs.csv')

# %%
users
# Out:
#      userID                                             Resume
# 0         1  Experienced software engineer with a degree in...
# 1         2  Marketing professional with expertise in socia...
# 2         3  Mechanical engineer specializing in product de...
# 3         4  Registered nurse with clinical experience in c...
# 4         5  Experienced elementary school teacher passiona...
# ..      ...                                                ...
# 495     496  Logistics manager with experience in supply ch...
# 496     497  UX/UI designer with a focus on user-centered d...
# 497     498  Corporate communications manager with expertis...
# 498     499  Chemical engineer specializing in process opti...
# 499     500  Family nurse practitioner with clinical experi...
#
# [500 rows x 2 columns]

# %%
jobs
# Out:
#      jobID                     Description  \
# 0        1               Software Engineer
# 1        2  Social Media Marketing Manager
# 2        3      Human Resources Specialist
# 3        4                Graphic Designer
# 4        5                    Data Analyst
# ..     ...                             ...
# 495    496        User Experience Designer
# 496    497        Public Relations Manager
# 497    498          Database Administrator
# 498    499      Email Marketing Specialist
# 499    500          Operations Coordinator
#
#                                            Requirement
# 0    Bachelor's degree in Computer Science or relat...
# 1    Bachelor's degree in Marketing, Communications...
# 2    Bachelor's degree in Human Resources Managemen...
# 3    Bachelor's degree in Graphic Design or related...
# 4    Bachelor's degree in Statistics, Mathematics, ...
# ..                                                 ...
# 495  Bachelor's degree in Graphic Design, Human-Com...
# 496  Bachelor's degree in Public Relations, Communi...
# 497  Bachelor's degree in Computer Science, Informa...
# 498  Bachelor's degree in Marketing, Communications...
# 499  Bachelor's degree in Business Administration, ...
#
# [500 rows x 3 columns]

# %%
apps
# Out:
#      userID  jobID Applied Perfect Fit  \
# 0         1      1     Yes         Yes
# 1         1      6     Yes         Yes
# 2         2      2     Yes         Yes
# 3         3     12     Yes         Yes
# 4         4      8     Yes         Yes
# ..      ...    ...     ...         ...
# 972     451    496     Yes         Yes
# 973     452    497     Yes         Yes
# 974     454    498     Yes         Yes
# 975     455    499     Yes         Yes
# 976     456    500     Yes         Yes
#
#                                                  Notes
# 0    The user is an experienced software engineer w...
# 1    With skills in cloud computing and full-stack ...
# 2    The user a marketing professional meets the re...
# 3    The mechanical engineer's expertise in CAD sof...
# 4    As a registered nurse with clinical experience...
# ..                                                 ...
# 972  Matches perfectly. Holds a degree in Logistics...
# 973  Matches perfectly. Holds a degree in Interacti...
# 974  Matches perfectly. Holds a degree in Communica...
# 975  Matches perfectly. Holds a degree in Chemical ...
# 976  Matches perfectly. Holds a Master's degree in ...
#
# [977 rows x 5 columns]

# %% [markdown]
# # preprocess

# %% [markdown]
# ## users

# %% [markdown]
# ### clean text

# %%
users['clean_text']=users['Resume'].apply(clean_text)
users['non_stop_text']=users['clean_text'].apply(remove_stopwords)

# %%
users.head()
# Out:
#    userID                                             Resume  \
# 0       1  Experienced software engineer with a degree in...
# 1       2  Marketing professional with expertise in socia...
# 2       3  Mechanical engineer specializing in product de...
# 3       4  Registered nurse with clinical experience in c...
# 4       5  Experienced elementary school teacher passiona...
#
#                                           clean_text  \
# 0  experienced software engineer with a degree in...
# 1  marketing professional with expertise in socia...
# 2  mechanical engineer specializing in product de...
# 3  registered nurse with clinical experience in c...
# 4  experienced elementary school teacher passiona...
#
#                                        non_stop_text
# 0  experienced software engineer degree computer ...
# 1  marketing professional expertise social media ...
# 2  mechanical engineer specializing product desig...
# 3  registered nurse clinical experience critical ...
# 4  experienced elementary school teacher passiona...

# %% [markdown]
# ### extract informations

# %%
nlp = spacy.load("en_core_web_lg")
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk("/content/drive/MyDrive/data/entity_rulers/skill_ruler.jsonl")
users['skills']=users['non_stop_text'].apply(get_skills)
users.head()
# Out:
#    userID                                             Resume  \
# 0       1  Experienced software engineer with a degree in...
# 1       2  Marketing professional with expertise in socia...
# 2       3  Mechanical engineer specializing in product de...
# 3       4  Registered nurse with clinical experience in c...
# 4       5  Experienced elementary school teacher passiona...
#
#                                           clean_text  \
# 0  experienced software engineer with a degree in...
# 1  marketing professional with expertise in socia...
# 2  mechanical engineer specializing in product de...
# 3  registered nurse with clinical experience in c...
# 4  experienced elementary school teacher passiona...
#
#                                        non_stop_text  \
# 0  experienced software engineer degree computer ...
# 1  marketing professional expertise social media ...
# 2  mechanical engineer specializing product desig...
# 3  registered nurse clinical experience critical ...
# 4  experienced elementary school teacher passiona...
#
#                                               skills
# 0  [software, computer science, java, python, sta...
# 1  [marketing, social media, management, digital,...
# 2  [product design, manufacturing processes, mech...
# 3  [clinical, critical care, advanced, life support]
# 4  [student development, education, training, lit...

# %%
nlp = spacy.load("en_core_web_lg")
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk("/content/drive/MyDrive/data/entity_rulers/degree_ruler.jsonl")
users['degrees']=users['non_stop_text'].apply(get_degree)
users.head()
# Out:
#    userID                                             Resume  \
# 0       1  Experienced software engineer with a degree in...
# 1       2  Marketing professional with expertise in socia...
# 2       3  Mechanical engineer specializing in product de...
# 3       4  Registered nurse with clinical experience in c...
# 4       5  Experienced elementary school teacher passiona...
#
#                                           clean_text  \
# 0  experienced software engineer with a degree in...
# 1  marketing professional with expertise in socia...
# 2  mechanical engineer specializing in product de...
# 3  registered nurse with clinical experience in c...
# 4  experienced elementary school teacher passiona...
#
#                                        non_stop_text  \
# 0  experienced software engineer degree computer ...
# 1  marketing professional expertise social media ...
# 2  mechanical engineer specializing product desig...
# 3  registered nurse clinical experience critical ...
# 4  experienced elementary school teacher passiona...
#
#                                               skills     degrees
# 0  [software, computer science, java, python, sta...          []
# 1  [marketing, social media, management, digital,...          []
# 2  [product design, manufacturing processes, mech...          []
# 3  [clinical, critical care, advanced, life support]  [bachelor]
# 4  [student development, education, training, lit...          []

# %%
nlp = spacy.load("en_core_web_lg")
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk("/content/drive/MyDrive/data/entity_rulers/majors_ruler.jsonl")
users['majors']=users['non_stop_text'].apply(get_majors)
users.head()
# Out:
#    userID                                             Resume  \
# 0       1  Experienced software engineer with a degree in...
# 1       2  Marketing professional with expertise in socia...
# 2       3  Mechanical engineer specializing in product de...
# 3       4  Registered nurse with clinical experience in c...
# 4       5  Experienced elementary school teacher passiona...
#
#                                           clean_text  \
# 0  experienced software engineer with a degree in...
# 1  marketing professional with expertise in socia...
# 2  mechanical engineer specializing in product de...
# 3  registered nurse with clinical experience in c...
# 4  experienced elementary school teacher passiona...
#
#                                        non_stop_text  \
# 0  experienced software engineer degree computer ...
# 1  marketing professional expertise social media ...
# 2  mechanical engineer specializing product desig...
# 3  registered nurse clinical experience critical ...
# 4  experienced elementary school teacher passiona...
#
#                                               skills     degrees  \
# 0  [software, computer science, java, python, sta...          []
# 1  [marketing, social media, management, digital,...          []
# 2  [product design, manufacturing processes, mech...          []
# 3  [clinical, critical care, advanced, life support]  [bachelor]
# 4  [student development, education, training, lit...          []
#
#                                            majors
# 0                              [computer science]
# 1                                              []
# 2  [mechanical engineering, software engineering]
# 3                                       [nursing]
# 4                                              []

# %% [markdown]
# ### get dominant topic

# %%
users['topic'] = users['skills'].apply(lambda x: classify_text(lda_model, x))
users.head()
# Out:
#    userID                                             Resume  \
# 0       1  Experienced software engineer with a degree in...
# 1       2  Marketing professional with expertise in socia...
# 2       3  Mechanical engineer specializing in product de...
# 3       4  Registered nurse with clinical experience in c...
# 4       5  Experienced elementary school teacher passiona...
#
#                                           clean_text  \
# 0  experienced software engineer with a degree in...
# 1  marketing professional with expertise in socia...
# 2  mechanical engineer specializing in product de...
# 3  registered nurse with clinical experience in c...
# 4  experienced elementary school teacher passiona...
#
#                                        non_stop_text  \
# 0  experienced software engineer degree computer ...
# 1  marketing professional expertise social media ...
# 2  mechanical engineer specializing product desig...
# 3  registered nurse clinical experience critical ...
# 4  experienced elementary school teacher passiona...
#
#                                               skills     degrees  \
# 0  [software, computer science, java, python, sta...          []
# 1  [marketing, social media, management, digital,...          []
# 2  [product design, manufacturing processes, mech...          []
# 3  [clinical, critical care, advanced, life support]  [bachelor]
# 4  [student development, education, training, lit...          []
#
#                                            majors  topic
# 0                              [computer science]     12
# 1                                              []     19
# 2  [mechanical engineering, software engineering]      7
# 3                                       [nursing]      8
# 4                                              []      3

# %% [markdown]
# ## jobs

# %%
jobs['text']=jobs['Description']+" "+jobs['Requirement']
jobs['clean_text']=jobs['text'].apply(clean_text)
jobs['non_stop_text']=jobs['clean_text'].apply(remove_stopwords)

nlp = spacy.load("en_core_web_lg")
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk("/content/drive/MyDrive/data/entity_rulers/degree_ruler.jsonl")
jobs['degrees']=jobs['non_stop_text'].apply(get_degree)

nlp = spacy.load("en_core_web_lg")
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk("/content/drive/MyDrive/data/entity_rulers/majors_ruler.jsonl")
jobs['majors']=jobs['non_stop_text'].apply(get_majors)

nlp = spacy.load("en_core_web_lg")
ruler = nlp.add_pipe("entity_ruler")
ruler.from_disk("/content/drive/MyDrive/data/entity_rulers/skill_ruler.jsonl")
jobs['skills']=jobs['non_stop_text'].apply(get_skills)
jobs['topic'] = jobs['skills'].apply(lambda x: classify_text(lda_model, x))
jobs.head()
# Out:
#    jobID                     Description  \
# 0      1               Software Engineer
# 1      2  Social Media Marketing Manager
# 2      3      Human Resources Specialist
# 3      4                Graphic Designer
# 4      5                    Data Analyst
#
#                                          Requirement  \
# 0  Bachelor's degree in Computer Science or relat...
# 1  Bachelor's degree in Marketing, Communications...
# 2  Bachelor's degree in Human Resources Managemen...
# 3  Bachelor's degree in Graphic Design or related...
# 4  Bachelor's degree in Statistics, Mathematics, ...
#
#                                                 text  \
# 0  Software Engineer Bachelor's degree in Compute...
# 1  Social Media Marketing Manager Bachelor's degr...
# 2  Human Resources Specialist Bachelor's degree i...
# 3  Graphic Designer Bachelor's degree in Graphic ...
# 4  Data Analyst Bachelor's degree in Statistics, ...
#
#                                           clean_text  \
# 0  software engineer bachelor s degree in compute...
# 1  social media marketing manager bachelor s degr...
# 2  human resources specialist bachelor s degree i...
# 3  graphic designer bachelor s degree in graphic ...
# 4  data analyst bachelor s degree in statistics m...
#
#                                        non_stop_text     degrees  \
# 0  software engineer bachelor degree computer sci...  [bachelor]
# 1  social media marketing manager bachelor degree...  [bachelor]
# 2  human resources specialist bachelor degree hum...  [bachelor]
# 3  graphic designer bachelor degree graphic desig...  [bachelor]
# 4  data analyst bachelor degree statistics mathem...  [bachelor]
#
#                             majors  \
# 0               [computer science]
# 1                 [communications]
# 2                               []
# 3                               []
# 4  [mathematics, computer science]
#
#                                               skills  topic
# 0  [software, computer science, programming langu...     12
# 1  [social media marketing, marketing, communicat...     19
# 2  [human resources, human resources, management,...     15
# 3  [graphic design, adobe creative suite, print, ...     19
# 4  [data, statistics, mathematics, computer scien...     11

# %% [markdown]
# # prepare text for embeddings

# %%
def concatenate_features(row):
    degree_str = "degree: " + " ".join(row['degrees'])+" . " if row['degrees'] else ""
    major_str = "majors: " + " ".join(row['majors'])+" . " if row['majors'] else ""
    skills_str = "skills: " + " ".join(row['skills'])+" . " if row['skills'] else ""
    return f"{degree_str} {major_str} {skills_str}".strip()

# %%
users['text_emb'] = users.apply(concatenate_features, axis=1)

# %%
users
# Out:
#      userID                                             Resume  \
# 0         1  Experienced software engineer with a degree in...
# 1         2  Marketing professional with expertise in socia...
# 2         3  Mechanical engineer specializing in product de...
# 3         4  Registered nurse with clinical experience in c...
# 4         5  Experienced elementary school teacher passiona...
# ..      ...                                                ...
# 495     496  Logistics manager with experience in supply ch...
# 496     497  UX/UI designer with a focus on user-centered d...
# 497     498  Corporate communications manager with expertis...
# 498     499  Chemical engineer specializing in process opti...
# 499     500  Family nurse practitioner with clinical experi...
#
#                                             clean_text  \
# 0    experienced software engineer with a degree in...
# 1    marketing professional with expertise in socia...
# 2    mechanical engineer specializing in product de...
# 3    registered nurse with clinical experience in c...
# 4    experienced elementary school teacher passiona...
# ..                                                 ...
# 495  logistics manager with experience in supply ch...
# 496  ux ui designer with a focus on user centered d...
# 497  corporate communications manager with expertis...
# 498  chemical engineer specializing in process opti...
# 499  family nurse practitioner with clinical experi...
#
#                                          non_stop_text  \
# 0    experienced software engineer degree computer ...
# 1    marketing professional expertise social media ...
# 2    mechanical engineer specializing product desig...
# 3    registered nurse clinical experience critical ...
# 4    experienced elementary school teacher passiona...
# ..                                                 ...
# 495  logistics manager experience supply chain opti...
# 496  ux ui designer focus user centered design prin...
# 497  corporate communications manager expertise int...
# 498  chemical engineer specializing process optimiz...
# 499  family nurse practitioner clinical experience ...
#
#                                                 skills     degrees  \
# 0    [software, computer science, java, python, sta...          []
# 1    [marketing, social media, management, digital,...          []
# 2    [product design, manufacturing processes, mech...          []
# 3    [clinical, critical care, advanced, life support]  [bachelor]
# 4    [student development, education, training, lit...          []
# ..                                                 ...         ...
# 495  [logistics, supply chain optimization, warehou...          []
# 496  [ux, ui, focus, user centered design, principl...          []
# 497  [corporate communications, internal external c...          []
# 498  [process optimization, chemical engineering, p...          []
# 499           [family, clinical, primary care, family]    [master]
#
#                                                majors  topic  \
# 0                                  [computer science]     12
# 1                                                  []     19
# 2      [mechanical engineering, software engineering]      7
# 3                                           [nursing]      8
# 4                                                  []      3
# ..                                                ...    ...
# 495                                                []     16
# 496                                                []     12
# 497  [communications, communications, communications]     19
# 498                            [chemical engineering]      2
# 499                                         [nursing]      8
#
#                                               text_emb
# 0    majors: computer science .  skills: software c...
# 1    skills: marketing social media management digi...
# 2    majors: mechanical engineering software engine...
# 3    degree: bachelor .  majors: nursing .  skills:...
# 4    skills: student development education training...
# ..                                                 ...
# 495  skills: logistics supply chain optimization wa...
# 496  skills: ux ui focus user centered design princ...
# 497  majors: communications communications communic...
# 498  majors: chemical engineering .  skills: proces...
# 499  degree: master .  majors: nursing .  skills: f...
#
# [500 rows x 9 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['skills', 'degrees', 'majors'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# users['userID'].plot(kind='hist', bins=20, title='userID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# users['topic'].plot(kind='hist', bins=20, title='topic')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# users.plot(kind='scatter', x='userID', y='topic', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['userID']
#   ys = series['topic']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = users.sort_values('userID', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('userID')
# _ = plt.ylabel('topic')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['userID']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'userID'}, axis=1)
#               .sort_values('userID', ascending=True))
#   xs = counted['userID']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = users.sort_values('userID', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('userID')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# users['userID'].plot(kind='line', figsize=(8, 4), title='userID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# users['topic'].plot(kind='line', figsize=(8, 4), title='topic')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
jobs['text_emb'] = jobs.apply(concatenate_features, axis=1)

# %%
jobs
# Out:
#      jobID                     Description  \
# 0        1               Software Engineer
# 1        2  Social Media Marketing Manager
# 2        3      Human Resources Specialist
# 3        4                Graphic Designer
# 4        5                    Data Analyst
# ..     ...                             ...
# 495    496        User Experience Designer
# 496    497        Public Relations Manager
# 497    498          Database Administrator
# 498    499      Email Marketing Specialist
# 499    500          Operations Coordinator
#
#                                            Requirement  \
# 0    Bachelor's degree in Computer Science or relat...
# 1    Bachelor's degree in Marketing, Communications...
# 2    Bachelor's degree in Human Resources Managemen...
# 3    Bachelor's degree in Graphic Design or related...
# 4    Bachelor's degree in Statistics, Mathematics, ...
# ..                                                 ...
# 495  Bachelor's degree in Graphic Design, Human-Com...
# 496  Bachelor's degree in Public Relations, Communi...
# 497  Bachelor's degree in Computer Science, Informa...
# 498  Bachelor's degree in Marketing, Communications...
# 499  Bachelor's degree in Business Administration, ...
#
#                                                   text  \
# 0    Software Engineer Bachelor's degree in Compute...
# 1    Social Media Marketing Manager Bachelor's degr...
# 2    Human Resources Specialist Bachelor's degree i...
# 3    Graphic Designer Bachelor's degree in Graphic ...
# 4    Data Analyst Bachelor's degree in Statistics, ...
# ..                                                 ...
# 495  User Experience Designer Bachelor's degree in ...
# 496  Public Relations Manager Bachelor's degree in ...
# 497  Database Administrator Bachelor's degree in Co...
# 498  Email Marketing Specialist Bachelor's degree i...
# 499  Operations Coordinator Bachelor's degree in Bu...
#
#                                             clean_text  \
# 0    software engineer bachelor s degree in compute...
# 1    social media marketing manager bachelor s degr...
# 2    human resources specialist bachelor s degree i...
# 3    graphic designer bachelor s degree in graphic ...
# 4    data analyst bachelor s degree in statistics m...
# ..                                                 ...
# 495  user experience designer bachelor s degree in ...
# 496  public relations manager bachelor s degree in ...
# 497  database administrator bachelor s degree in co...
# 498  email marketing specialist bachelor s degree i...
# 499  operations coordinator bachelor s degree in bu...
#
#                                          non_stop_text     degrees  \
# 0    software engineer bachelor degree computer sci...  [bachelor]
# 1    social media marketing manager bachelor degree...  [bachelor]
# 2    human resources specialist bachelor degree hum...  [bachelor]
# 3    graphic designer bachelor degree graphic desig...  [bachelor]
# 4    data analyst bachelor degree statistics mathem...  [bachelor]
# ..                                                 ...         ...
# 495  user experience designer bachelor degree graph...  [bachelor]
# 496  public relations manager bachelor degree publi...  [bachelor]
# 497  database administrator bachelor degree compute...  [bachelor]
# 498  email marketing specialist bachelor degree mar...  [bachelor]
# 499  operations coordinator bachelor degree busines...  [bachelor]
#
#                                majors  \
# 0                  [computer science]
# 1                    [communications]
# 2                                  []
# 3                                  []
# 4     [mathematics, computer science]
# ..                                ...
# 495                                []
# 496  [communications, communications]
# 497                [computer science]
# 498                  [communications]
# 499         [business administration]
#
#                                                 skills  topic  \
# 0    [software, computer science, programming langu...     12
# 1    [social media marketing, marketing, communicat...     19
# 2    [human resources, human resources, management,...     15
# 3    [graphic design, adobe creative suite, print, ...     19
# 4    [data, statistics, mathematics, computer scien...     11
# ..                                                 ...    ...
# 495  [user experience, graphic design, human comput...     19
# 496  [public relations, public relations, communica...     19
# 497  [database, computer science, information techn...     12
# 498  [marketing, marketing, communications, marketi...     19
# 499  [operations, business, administration, operati...      2
#
#                                               text_emb
# 0    degree: bachelor .  majors: computer science ....
# 1    degree: bachelor .  majors: communications .  ...
# 2    degree: bachelor .   skills: human resources h...
# 3    degree: bachelor .   skills: graphic design ad...
# 4    degree: bachelor .  majors: mathematics comput...
# ..                                                 ...
# 495  degree: bachelor .   skills: user experience g...
# 496  degree: bachelor .  majors: communications com...
# 497  degree: bachelor .  majors: computer science ....
# 498  degree: bachelor .  majors: communications .  ...
# 499  degree: bachelor .  majors: business administr...
#
# [500 rows x 11 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['degrees', 'majors', 'skills'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# jobs['jobID'].plot(kind='hist', bins=20, title='jobID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# jobs['topic'].plot(kind='hist', bins=20, title='topic')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# jobs.plot(kind='scatter', x='jobID', y='topic', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['jobID']
#   ys = series['topic']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = jobs.sort_values('jobID', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('jobID')
# _ = plt.ylabel('topic')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['jobID']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'jobID'}, axis=1)
#               .sort_values('jobID', ascending=True))
#   xs = counted['jobID']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = jobs.sort_values('jobID', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('jobID')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# jobs['jobID'].plot(kind='line', figsize=(8, 4), title='jobID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# jobs['topic'].plot(kind='line', figsize=(8, 4), title='topic')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # change indexes

# %% [markdown]
# for mapping and graph creation , IDs need to be in range 0-(len(df)-1) , so we need IDs to start from 0 and not 1 like they are originally.

# %%
users['userID']=users['userID']-1
jobs['jobID']=jobs['jobID']-1
apps['userID']=apps['userID']-1
apps['jobID']=apps['jobID']-1

# %%
apps
# Out:
#      userID  jobID Applied Perfect Fit  \
# 0         0      0     Yes         Yes
# 1         0      5     Yes         Yes
# 2         1      1     Yes         Yes
# 3         2     11     Yes         Yes
# 4         3      7     Yes         Yes
# ..      ...    ...     ...         ...
# 972     450    495     Yes         Yes
# 973     451    496     Yes         Yes
# 974     453    497     Yes         Yes
# 975     454    498     Yes         Yes
# 976     455    499     Yes         Yes
#
#                                                  Notes
# 0    The user is an experienced software engineer w...
# 1    With skills in cloud computing and full-stack ...
# 2    The user a marketing professional meets the re...
# 3    The mechanical engineer's expertise in CAD sof...
# 4    As a registered nurse with clinical experience...
# ..                                                 ...
# 972  Matches perfectly. Holds a degree in Logistics...
# 973  Matches perfectly. Holds a degree in Interacti...
# 974  Matches perfectly. Holds a degree in Communica...
# 975  Matches perfectly. Holds a degree in Chemical ...
# 976  Matches perfectly. Holds a Master's degree in ...
#
# [977 rows x 5 columns]

# %% [markdown]
# # save to csv

# %%
users.to_csv('/content/drive/MyDrive/data/chatgpt_datasets/processed_users.csv',index=False)
jobs.to_csv('/content/drive/MyDrive/data/chatgpt_datasets/processed_jobs.csv',index=False)
apps.to_csv('/content/drive/MyDrive/data/chatgpt_datasets/processed_apps.csv',index=False)
