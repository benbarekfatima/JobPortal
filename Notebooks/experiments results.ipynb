# %% [markdown]
# # connect to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # import

# %%
import pandas as pd

# %% [markdown]
# # best performance of each layer number

# %%
layers=pd.read_csv('/content/drive/MyDrive/data/results_layer_hidden_epoch_stable.csv')

# %%
layers.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
sort_order = ['NDCG@10', 'MAE', 'Precision@10', 'Recall@10', 'RMSE']

# Sort by the specified metrics
sorted_df = layers.sort_values(by=sort_order, ascending=[False, True, False, False, True])

# Group by 'model' and get the top row for each group
best_metrics_df = sorted_df.groupby('Model').head(1).reset_index(drop=True)

best_metrics_df
# Out:
#      Model  Hidden_Channel  Epochs   NDCG@10  Precision@10  Recall@10  \
# 0  Model_2              32      50  0.138373      0.030909   0.253535
# 1  Model_3              64      44  0.104272      0.018788   0.176768
# 2  Model_5              32      26  0.079526      0.016970   0.141919
#
#        RMSE       MAE
# 0  0.611069  0.542540
# 1  0.667286  0.601197
# 2  0.618977  0.547224

# %% [markdown]
# # hidden channels

# %%
model2 = layers.loc[(layers['Model'] == 'Model_2') & (layers['Epochs'] == 50)]

model2
# Out:
#        Model  Hidden_Channel  Epochs   NDCG@10  Precision@10  Recall@10  \
# 49   Model_2              32      50  0.138373      0.030909   0.253535
# 99   Model_2              64      50  0.098724      0.021212   0.190909
# 149  Model_2             128      50  0.094949      0.020000   0.177778
# 199  Model_2             256      50  0.083903      0.018182   0.164646
#
#          RMSE       MAE
# 49   0.611069  0.542540
# 99   0.655880  0.590254
# 149  0.655147  0.590028
# 199  0.651193  0.584390

# %% [markdown]
# # epochs

# %%
epochs=pd.read_csv('/content/drive/MyDrive/data/stable_results_model2_epochs.csv')

# %%
df_filtered = epochs[epochs['Epochs'] % 10 == 0]

# %%
df_filtered
# Out:
#     Unnamed: 0  Epochs   NDCG@10  Precision@10  Recall@10      RMSE       MAE
# 9            9      10  0.057331      0.014545   0.124242  0.591696  0.532827
# 19          19      20  0.093495      0.020606   0.185859  0.611057  0.543664
# 29          29      30  0.110441      0.024848   0.211111  0.596923  0.529193
# 39          39      40  0.120808      0.027273   0.218182  0.596038  0.525707
# 49          49      50  0.138373      0.030909   0.253535  0.611069  0.542540
# 59          59      60  0.122374      0.026667   0.225253  0.617581  0.549274
